# %% [markdown]
# Amod Marathe - 25050123073
#
# Experminet 10 - Study of Pandas library

# %%
# Introduction to Pandas
# Pandas : Panel Data
''' Used for :
structured data
'''
import pandas as pd
s = pd.Series([10,20,30,40,55])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    55
# dtype: int64

# %%
# create DataFrame
data  = {
    "Name": ["A","B","C"],
    "Marks": [85,90,78]
}
df = pd.DataFrame(data)
df
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
# find struxture of the DataFrame
df.shape
# Out:
# (3, 2)

# %%
df.ndim
print(df.size)
# Out:
# 6

# %%
# Display column Names
print(df.columns)
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
print(df.dtypes)
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
# Access Individual column
df["Name"]
# Out:
# 0    A
# 1    B
# 2    C
# Name: Name, dtype: object

# %%
df["Marks"]
# Out:
# 0    10
# 1    20
# 2    30
# Name: Marks, dtype: int64

# %%
df.loc[0,"Name"]
# Out:
# 'A'

# %%
df =pd.DataFrame(data)
print(df)
print(df.loc[0,"Marks"])
print(df.iloc[2,1])
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78
# 85
# 78

# %%
#Add  new column
''' If marks 80-90-first class
If Marks  >=90 - Distribution
If Marks >80 - second class'''
df["grade"]=["First Class","Distinction","Second Class"]
print(df)
# Out:
#   Name  Marks         grade
# 0    A     85   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
# Update Data in DataFrame
# Change marks of student A to 88.

df.iloc[0,1]=88
print(df)
# Out:
#   Name  Marks         grade
# 0    A     88   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
# delete a column
df1=df.drop("grade",axis=1)
print(df)
print(df1)
# Out:
#   Name  Marks         grade
# 0    A     88   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class
#   Name  Marks
# 0    A     88
# 1    B     90
# 2    C     78

# %%
# perform basic statistical analysis
mean1 = df["Marks"].mean()
mean1
# Out:
# np.float64(85.33333333333333)

# %%
min1 = df["Marks" ].min()
min1
# Out:
# 78

# %%
max1=df["Marks"].max()
max1
# Out:
# 90

# %%
# Apply condition (Filtering)
# Display students scoring more than 80.
df[df["Marks"]>80]
# Out:
#   Name  Marks        grade
# 0    A     88  First Class
# 1    B     90  Distinction
